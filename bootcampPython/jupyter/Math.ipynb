# %% [markdown]
# # Math

# %% [markdown]
# ## 4 Operators

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# ## Modulo(Mod)

# %%
7/4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %%
23 % 2
# Out:
# 1

# %%
20 % 2
# Out:
# 0

# %% [markdown]
# ## Power

# %%
2 ** 3
# Out:
# 8

# %%
4**0.5 #square root
# Out:
# 2.0

# %% [markdown]
# ## Order Of Operations

# %% [markdown]
# <br> 1. Parentheses <br> 2. Exponents <br> 3. Multiply/Divide <br> 4. Add/Subtract

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2 + 10) * (10 + 3)
# Out:
# 156
