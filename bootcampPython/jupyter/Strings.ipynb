# %% [markdown]
# # Strings

# %% [markdown]
# ## Examples

# %% [markdown]
# "Hello"

# %% [markdown]
# 'Hello'

# %% [markdown]
# "I don't do that"

# %%
string = "Hello"

# %%
string
# Out:
# 'Hello'

# %%
string[1]
# Out:
# 'e'

# %%
string[0::2]
# Out:
# 'Hlo'

# %%
'I'm going on a run'
# Out:
#   File "<ipython-input-66-0b29964ddaa6>", line 1
#     'I'm going on a run'
#        ^
# SyntaxError: invalid syntax

# %%
"I'm going on a run"
# Out:
# "I'm going on a run"

# %% [markdown]
# ## Print()

# %%
print("Hello")
# Out:
# Hello

# %%
"Hello World 1"
"Hello World 2"
# Out:
# 'Hello World 2'

# %%
print("Hello World 1")
print("Hello World 2")
# Out:
# Hello World 1
# Hello World 2

# %%
print("Hello \nworld")
# Out:
# Hello
# world

# %%
print("Hello \tworld")
# Out:
# Hello 	world

# %% [markdown]
# ## len()

# %%
len("Hello")
# Out:
# 5

# %%
len("I am hungry")
# Out:
# 11

# %%
len("Iamhungry")
# Out:
# 9

# %% [markdown]
# ## Indexing/Slicing

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring = "abcdefghijk"

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[::2]
# Out:
# 'acegik'

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %%
mystring[::-1]
# Out:
# 'kjihgfedcba'

# %% [markdown]
# ## Immutability

# %%
name = "Sam"

# %%
#name[0] = 'P' # Doesn't work

# %%
name = "Pam" #Works

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = "Hello World"

# %%
x + ", It is beatiful outside!"
# Out:
# 'Hello World, It is beatiful outside!'

# %%
x = x + ", It is beatiful outside!"

# %%
x
# Out:
# 'Hello World, It is beatiful outside!'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2'+ '3'
# Out:
# '23'
