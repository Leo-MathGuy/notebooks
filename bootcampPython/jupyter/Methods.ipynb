# %% [markdown]
# # Methods

# %% [markdown]
# ## What are they?

# %% [markdown]
# Methods are functions that are built in into functions.

# %% [markdown]
# ## List Methods

# %%
l = [1, 2, 3]

# %%
l.append(4)
l
# Out:
# [1, 2, 3, 4]

# %%
l.pop()
l
# Out:
# [1, 2, 3]

# %%
l.insert(0, 0)
l
# Out:
# [0, 1, 2, 3]

# %%
l.remove(0)
l
# Out:
# [1, 2, 3]
