# %% [markdown]
# # Sets

# %% [markdown]
# ## What are they?

# %% [markdown]
# Sets are unordered lists of unique objects

# %% [markdown]
# Every element is unique(1, 2, 2 makes an error)

# %% [markdown]
# ## Examples

# %%
s = set()

# %%
s
# Out:
# set()

# %%
s.add(1)

# %%
s
# Out:
# {1}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.add("three")

# %%
s
# Out:
# {1, 2, 'three'}

# %% [markdown]
# No effect --v

# %%
s.add(2)

# %%
s
# Out:
# {1, 2, 'three'}

# %%
list = [1, 3, 3, 5, 5, 5, 5, 7, 7, 7, 7, 7, 7, 9, 9, 9, 9, 9, 9, 9, 9]

# %%
set(list)
# Out:
# {1, 3, 5, 7, 9}
